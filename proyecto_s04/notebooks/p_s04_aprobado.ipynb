# %% [markdown]
# Hola **Jose**!
#
# Soy **Patricio Requena** 👋. Es un placer ser el revisor de tu proyecto el día de hoy!
#
# Revisaré tu proyecto detenidamente con el objetivo de ayudarte a mejorar y perfeccionar tus habilidades. Durante mi revisión, identificaré áreas donde puedas hacer mejoras en tu código, señalando específicamente qué y cómo podrías ajustar para optimizar el rendimiento y la claridad de tu proyecto. Además, es importante para mí destacar los aspectos que has manejado excepcionalmente bien. Reconocer tus fortalezas te ayudará a entender qué técnicas y métodos están funcionando a tu favor y cómo puedes aplicarlos en futuras tareas.
#
# _**Recuerda que al final de este notebook encontrarás un comentario general de mi parte**_, empecemos!
#
# Encontrarás mis comentarios dentro de cajas verdes, amarillas o rojas, ⚠️ **por favor, no muevas, modifiques o borres mis comentarios** ⚠️:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si todo está perfecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
#     Hola Patricio,
#
# Espero que estés muy bien. Quería agradecerte profundamente por el tiempo y los comentarios que dedicaste a la revisión de mi proyecto. Tus observaciones fueron sumamente valiosas para ajustar los análisis, corregir detalles y mejorar la claridad de las gráficas y conclusiones.
#
# He implementado las correcciones señaladas, incluidos los retoques estéticos en las visualizaciones y el desarrollo de las conclusiones faltantes. Tu feedback no solo enriqueció el proyecto, sino que también reforzó mi aprendizaje en el proceso.
#
# ¡Aprecio mucho tu apoyo y disposición!
# Quedo atento a cualquier comentario adicional.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (2da Iteracion)</b> <a class=“tocSkip”></a>
#
# Me alegro mucho que los comentarios aportaron a tu aprendizaje Jose! Espero que sigas aprendiendo mucho más y sigas teniendo la misma experiencia en el resto de tus proyectos para que te conviertas en un excelente profesional de los datos!
# </div>

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# * Exploración inicial de cada dataframe para enteder su estructura y contenido antes de procesarlos.
#
#   1. Cargar el dataframe asignandolos a una variable
#   2. Mostrar las primeras filas
#
#   3. Mostrar la informacion general de para conocer el rango, los tipos de datos y posibles valores ausentes.

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df_instacart_orders = pd.read_csv('/datasets/instacart_orders.csv', sep=';')
df_products = pd.read_csv('/datasets/products.csv', sep=';')
df_order_products = pd.read_csv('/datasets/order_products.csv', sep=';')
df_aisles = pd.read_csv('/datasets/aisles.csv', sep=';')
df_departments = pd.read_csv('/datasets/departments.csv', sep=';')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Buen trabajo importando las librerías y cargando tus datos en celdas diferentes, eso da un mejor orden al notebook
# </div>

# %%
df_instacart_orders.info()
print()
df_instacart_orders.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# ...

# %%
filas_instacart= df_instacart_orders.shape[0]
nulos_columna_instacart = df_instacart_orders['days_since_prior_order'].isnull().sum()
nulos_en_instacart = nulos_columna_instacart/filas_instacart * 100
print(f"Se identificaron {nulos_columna_instacart} valores nulos en la columna 'days_since_prior_order', ({nulos_en_instacart.round(2)}% del total).")
# Out:
# Se identificaron 28819 valores nulos en la columna 'days_since_prior_order', (6.02% del total).

# %%
df_products.info()
print()
df_products.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# ...

# %%
filas_products= df_products.shape[0]
nulos_columna_products = df_products['product_name'].isna().sum()
nulos_en_products = nulos_columna_products/filas_products * 100
print(f"Se identificaron {nulos_columna_products} valores nulos en la columna 'product_name', ({nulos_en_products.round(2)}% del total).")
# Out:
# Se identificaron 1258 valores nulos en la columna 'product_name', (2.53% del total).

# %%
df_departments.info()
print()
df_departments.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
df_aisles.info()
print()
df_aisles.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
df_order_products.info(show_counts=True)
print()
df_order_products.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB
#    order_id  product_id  add_to_cart_order  reordered
# 0   2141543       11440               17.0          0
# 1    567889        1560                1.0          1
# 2   2261212       26683                1.0          1
# 3    491251        8670               35.0          1
# 4   2571142        1940                5.0          1

# %%
filas_order_products = df_order_products.shape[0]
nulos_columna_order_products = df_order_products['add_to_cart_order'].isna().sum()
nulos_en_order_products = nulos_columna_order_products/filas_order_products * 100
print(f"Se identificaron {nulos_columna_order_products} valores nulos en la columna 'add_to_cart_order', ({nulos_en_order_products.round(2)}% del total).")
# Out:
# Se identificaron 836 valores nulos en la columna 'add_to_cart_order', (0.02% del total).

# %% [markdown]
# ## Conclusiones
#
# El análisis inicial de los 5 datases, permite obsevar la calidad y estructura inicial de los datos, destacando hallazgos relevantes sobre sus tipos de datos y posibles áreas de mejora. A continuación, los resultados clave por dataset:
#   * Consistencia en los tipos de datos (ajustes necesarios para normalización).
#     * Integridad de los datos (porcentajes de valores nulos y su posible causa).
#
# df_orders
# Con un rango de 478,967 registros por 6 columnas.
#   * Columnas `order_id`, `user_id`, `order_number`, `order_dow` y `order_hour_of_day`: enteros (int64), sin nulos.
#
#   * Columna `days_since_prior_order`: decimales (float64), normalizar los días a enteros (int64).
#     * Posibles nulos: 28,819 registros (6.02%), quizás corresponden al primer pedido (sin pedido anterior).
#
# df_products
# Con un rango de 49,694 registros por 4 columnas.
#   * Columnas `product_id`, `aisle_id`, `department_id`: enteros (int64), sin nulos.
#
#   * Columna `product_name`: texto (object).
#     * Posibles nulos: 1,258 registros (2.53%), quizás un error de registro o productos sin nombre.
#
# df_order_products
# Con un rango de 4,545,007 registros por 4 columnas.
#   * Columnas `order_id`, `product_id`, `reordered`: enteros (int64), sin nulos.
#
#   * Columna `add_to_cart_order`: decimal (float64),  normalizar los días a enteros (int64).
#     * Posible nulos: 836 registros (0.02%), quizás pedidos de un solo producto o añadidos automáticos.
#
# df_departments
# Con un rango de 21 registros por 2 columnas.
#   * Columna `department_id`: entero (int64), sin nulos.
#   * Columna `department`: texto (object), sin nulos.
#
# df_aisles
# Con un rango de 134 registros por 2 columnas.
#   * Columna `aisle_id`: entero (int64), sin nulos.
#   * Columna `aisle`: texto (object), sin nulos.

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# 1. Manejo de Valores Duplicados
#
# * Detección:
#
#   Identificar duplicados exactos en todas las columnas.
#   Buscar duplicados en columnas clave (ej. IDs, nombres únicos).
#
# * Validación:
#
#   Verificar si los duplicados son errores o casos válidos.
#
# * Eliminación:
#
#   Borrar registros duplicados irrelevantes.
#
# 2. Manejo de Valores Ausentes (NaN/nulos)
#
# * Detección:
#
#   Contabilizar valores faltantes por columna.
#   Analizar patrones (ej. si se agrupan en ciertas categorías).
#
# * Estrategia de Eliminación:
#
#   Eliminar: Si los nulos son pocos y no afectan el análisis.
#
#   Rellenar:
#   Con "unknown" (datos categóricos).
#   Con media/mediana (numéricos) si es relevante.
#
#   Preservar: Si los nulos son informativos.

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
pedidos_duplicados = df_instacart_orders.duplicated().sum()
print(f'Se identificaron {pedidos_duplicados} pedidos duplicados.')
# Out:
# Se identificaron 15 pedidos duplicados.

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?

# %%
pedidos_2am = df_instacart_orders['order_hour_of_day'] == 2
pedidos_miercoles = df_instacart_orders['order_dow'] == 3
pedidos_miercoles_2am = df_instacart_orders[ pedidos_miercoles & pedidos_2am ]
pedidos_duplicados_miercoles_2am = pedidos_miercoles_2am.duplicated().sum()
print(f'Se identificaron {len(pedidos_miercoles_2am)} pedidos el miércoles a las 2:00 a.m. identificando {pedidos_duplicados_miercoles_2am} duplicados.')
# Out:
# Se identificaron 121 pedidos el miércoles a las 2:00 a.m. identificando 15 duplicados.

# %% [markdown]
# ¿Qué sugiere este resultado?

# %%
df_instacart_orders.drop_duplicates(inplace=True)

# %%
revision_pedidos_duplicados = df_instacart_orders.duplicated().sum()
print(f'Tras la depuración se identificaron {revision_pedidos_duplicados} pedidos duplicados.' )
# Out:
# Tras la depuración se identificaron 0 pedidos duplicados.

# %%
id_pedidos_duplicados = df_instacart_orders['order_id'].duplicated().sum()
print(f"Se identificaron {id_pedidos_duplicados} IDs de pedidos duplicados.")
# Out:
# Se identificaron 0 IDs de pedidos duplicados.

# %% [markdown]
# Durante una búsqueda inicial, identifiqué 15 casos de pedidos duplicados. Para validar este hallazgo, realicé un filtro de pedidos realizados los miércoles a las 2:00 a.m., donde confirmé la misma cantidad de casos. Este patrón sugiere que la duplicación podría estar relacionada con procesos de mantenimiento o actualización de la plataforma. Como medida correctiva, procedí a eliminar estos registros duplicados.
#
# Como siguiente paso, verifiqué que no existieran valores duplicados en el campo de ID de pedido, el cual, por diseño, debe ser un identificador único. Esta revisión confirmó que no había repeticiones en este campo crítico.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Correcto! Muy bien aplicado el filtro y el análisis redactado
# </div>

# %% [markdown]
# ### `products` data frame

# %%
productos_duplicados =  df_products.duplicated().sum()
print(f'Se identificaron {productos_duplicados} productos duplicados.')
# Out:
# Se identificaron 0 productos duplicados.

# %%
id_departamentos_duplicados = df_products['department_id'].duplicated().sum()
print(f"Se identificaron {id_departamentos_duplicados} IDs de departamentos duplicados.")
# Out:
# Se identificaron 49673 IDs de departamentos duplicados.

# %%
nombres_productos_duplicados = df_products['product_name'].duplicated().sum()
print(f"Se identificaron {nombres_productos_duplicados} nombres de productos duplicados.")
df_products['product_name'] = df_products['product_name'].str.upper()
print('Despues de convertir los nombres a mayúsculas')
print(f"Se identificaron {df_products['product_name'].duplicated().sum()} nombres de productos duplicados.")
# Out:
# Se identificaron 1257 nombres de productos duplicados.
# Despues de convertir los nombres a mayúsculas
# Se identificaron 1361 nombres de productos duplicados.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Buen trabajo aplicando la transformación sobre la columna product_name, guardando el resultado evitas posibles problemas de análisis por la forma en la que se escribe el producto más adelante
# </div>

# %%
nombres_no_faltantes = df_products['product_name'].notna()
nombres_duplicados = df_products.duplicated(subset=['product_name'], keep=False)
nombres_duplicados_productos_no_faltantes = df_products[ nombres_no_faltantes & nombres_duplicados ]
print(f" Se identificaron {len(nombres_duplicados_productos_no_faltantes)} nombres de productos duplicados no faltantes")
# Out:
#  Se identificaron 207 nombres de productos duplicados no faltantes

# %% [markdown]
# En una revisión inicial no se encontraron filas completamente duplicadas. Al examinar los IDs de departamento se identificaron 49,673 registros repetidos, resultado esperado dado el volumen del catálogo. Posteriormente, al analizar los nombres de productos se detectaron 1,257 posibles duplicados, cifra que aumentó a 1,361 tras normalizar los textos a mayúsculas. Al filtrar específicamente los nombres de productos duplicados con valores existentes (excluyendo ausentes), se confirmaron 206 casos que requieren validación, mientras que los restantes corresponden a registros con valores faltantes.
#  Estos resultados evidencian la necesidad de implementar controles de calidad para nombres de productos.

# %% [markdown]
# ### `departments` data frame

# %%
departamentos_duplicados = df_departments.duplicated().sum()
print(f'Se identificaron {departamentos_duplicados} departamentos duplicados.')
# Out:
# Se identificaron 0 departamentos duplicados.

# %%
ids_departamento_duplicados = df_departments['department_id'].duplicated().sum()
print(f'Se identificaron {ids_departamento_duplicados} IDs de departamento duplicados.')
# Out:
# Se identificaron 0 IDs de departamento duplicados.

# %% [markdown]
# La revisión inicial no encontró filas completamente duplicadas en el dataset. Posteriormente, al verificar posibles duplicados en los IDs de departamento, tampoco se identificaron casos repetidos, confirmando la integridad de estos identificadores únicos.

# %% [markdown]
# ### `aisles` data frame

# %%
pasillos_duplicados = df_aisles.duplicated().sum()
print(f'Se identificaron {pasillos_duplicados} pasillos duplicados.')
# Out:
# Se identificaron 0 pasillos duplicados.

# %%
ids_pasillos_duplicados = df_aisles['aisle_id'].duplicated().sum()
print(f"Se identificaron {ids_pasillos_duplicados} IDs de pasillos duplicados.")
# Out:
# Se identificaron 0 IDs de pasillos duplicados.

# %% [markdown]
# La revisión inicial no encontró filas completamente duplicadas en el dataset. Posteriormente, al verificar posibles duplicados en los IDs de pasillo, tampoco se identificaron casos repetidos, confirmando la integridad de estos identificadores únicos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Buen trabajo con la revisión de estos últimos datasets
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
pedido_de_producto_duplicados = df_order_products.duplicated().sum()
print(f'Se identificaron {pedido_de_producto_duplicados} pedidos de prductos duplicados.')
# Out:
# Se identificaron 0 pedidos de prductos duplicados.

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso
id_pedido_duplicados = df_order_products['order_id'].duplicated().sum()
print(f"Se identificaron {id_pedido_duplicados} IDs de pedidos duplicados.")
# Out:
# Se identificaron 4094961 IDs de pedidos duplicados.

# %% [markdown]
# En la revisión inicial no se encontraron filas completamente duplicadas. Al analizar los IDs de orden, se identificaron 4,094,961 repeticiones, lo cual es normal y corresponde a pedidos que contienen múltiples artículos (un mismo ID de orden asociado a diferentes productos).

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
nombres_productos_ausentes = df_products['product_name'].isna().sum()
print(f"Se identificaron {nombres_productos_ausentes} nombres de productos ausentes.")
# Out:
# Se identificaron 1258 nombres de productos ausentes.

# %% [markdown]
# Se encontraron valores ausentes en nombre del producto

# %%
productos_ausentes_pasillo_100 = (df_products[df_products['product_name'].isna()]['aisle_id'] == 100).sum()
print(f"Se identificaron {productos_ausentes_pasillo_100} valores ausentes relacionados con el pasillo con ID 100.")
# Out:
# Se identificaron 1258 valores ausentes relacionados con el pasillo con ID 100.

# %% [markdown]
# Los valores ausentes estan relacionados con el pasillo 100.

# %%
productos_ausentes_departamento_21 = (df_products[df_products['product_name'].isna()]['department_id'] == 21).sum()
print(f"Se identificaron {productos_ausentes_departamento_21} valores ausentes relacionados con el departamento con ID 21.")
# Out:
# Se identificaron 1258 valores ausentes relacionados con el departamento con ID 21.

# %% [markdown]
# Los valores ausentes estan relacionados con el pasillo 21.

# %%
print(df_departments.loc[20,'department'])
print(df_aisles.loc[99,'aisle'])
# Out:
# missing
# missing

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Bien hecho! Aplicaste los filtros sobre los datasets correctos para obtener el resultado. Siempre hay que revisar las posibles razones de que exista un valor ausente antes de aplicar cualquier proceso
# </div>

# %% [markdown]
# Al verificar las categorias podemos obsevar que pertenecen a "missing"

# %%
df_products.fillna({'product_name': 'Unknown'}, inplace=True)

# %% [markdown]
# Remplace los valores nulos con 'Unknown'

# %% [markdown]
# ### `orders` data frame

# %%
print('Estos son los valores ausentes:')
print(df_instacart_orders.isna().sum())
# Out:
# Estos son los valores ausentes:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28817
# dtype: int64

# %%
compras_frecuentes_nulos = df_instacart_orders[df_instacart_orders["order_number"] > 1]["days_since_prior_order"].isna().sum()
print(f" Se identificaron {compras_frecuentes_nulos} valores ausentes en el primer pedido del cliente")
# Out:
#  Se identificaron 0 valores ausentes en el primer pedido del cliente

# %% [markdown]
# Los valores faltantes corresponden exclusivamente a primeros pedidos, lo cual es esperable porque al no existir un pedido anterior registrado, no hay referencia temporal para calcular el intervalo entre órdenes.

# %% [markdown]
# ### `order_products` data frame

# %%
print('Estos son los valores ausentes:')
print(df_order_products.isna().sum())
# Out:
# Estos son los valores ausentes:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
print(f"El valor mínimo: {df_order_products['add_to_cart_order'].min()}, valor máximo: {df_order_products['add_to_cart_order'].max()} en la columna.")
# Out:
# El valor mínimo: 1.0, valor máximo: 64.0 en la columna.

# %% [markdown]
# Se identificaron 836 valores nulos en esta columna, mientras que los valores existentes presentan un rango de 1 a 64 (que representa el máximo de artículos en una compra), lo que sugiere que estos nulos probablemente corresponden a pedidos de un solo producto (donde no aplica la posición en el carrito), siendo por tanto valores esperables y no errores en los datos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Buen trabajo buscando los valores máximos y mínimos! Aplicaste los métodos adecuados para esta operación
# </div>

# %%
ausentes_en_carrito = df_order_products[df_order_products['add_to_cart_order'].isna()]['order_id'].unique()
ids_con_ausentes_en_carrito =  df_order_products[df_order_products['order_id'].isin(ausentes_en_carrito)]

# %%
conteo_productos = ids_con_ausentes_en_carrito.groupby('order_id')['product_id'].count()
pedidos_mas_64 = conteo_productos[conteo_productos > 64]
pedidos_mas_64.min()
# Out:
# 65

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Para revisar si los pedidos con valores ausentes tienen o no más de 64 pedidos primero deberías buscar los valores NaN sobre la columna add_to_cart_order y luego deberías usar las order_id que que tienes en la variable `ids_con_ausentes_en_carrito` suponiendo que sea donde guardas el resultado anterior (Solo toma los valores de la columna order_id) y filtrar en el dataset original utilizando `isin()` y luego si agrupar por order_id y contar en product_id, ya que de la forma en que lo estás haciendo solo cuenta cuantos valores ausentes hay por órden pero puede que tengas órdenes que tiene valores ausentes y también valores que no lo son y lo que interesa es contar todos estos datos.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (2da Iteracion)</b> <a class=“tocSkip”></a>
#
# Muy bien! Cómo peudes observar ahora el resultado es distinto y totalmente diferente al anterior. Siempre hay que tener cuidad con la forma en la que se realizan los filtros ya que de esto dependerá los resultados que obtengamos y las conclusiones que tomemos.
# </div>

# %% [markdown]
# Se almacenaron todos los IDs de pedidos con valores ausentes en "add_to_cart_order" para su posterior análisis. Al agrupar estos pedidos por su ID y contar el número de productos asociados a cada uno, se encontró que el valor mínimo del conteo fue 65, lo que confirma que los pedidos con  valores nulos tienen mas de 64 productos.

# %%
df_order_products['add_to_cart_order'] = df_order_products['add_to_cart_order'].fillna(999)
df_order_products['add_to_cart_order'] = df_order_products['add_to_cart_order'].astype(int)

# %% [markdown]
# Los valores ausentes en la columna "agregar al carrito" fueron reemplazados con el código 999 y posteriormente se convirtió la columna al tipo entero, lo que normaliza los datos para su procesamiento mientras se mantiene la identificación de los casos especiales (pedidos de un solo producto que originalmente mostraban valores nulos). Esta codificación permite diferenciar claramente estos registros (ahora marcados como 999) en análisis posteriores, garantizando que la información sobre pedidos unitarios no se pierda durante la transformación de los datos.

# %% [markdown]
# ## Conclusiones
#
# El análisis de duplicados en los datasets de Instacart reveló hallazgos clave: en instacart_orders, se identificaron y eliminaron 15 pedidos duplicados con un patrón temporal (miércoles a las 2:00 a.m.), posiblemente vinculado a procesos técnicos de la plataforma, mientras se confirmó la unicidad de los IDs de pedido. En products, se detectaron 206 nombres de productos duplicados (tras normalización) que requieren validación, junto con registros repetidos en IDs de departamento (esperados por el tamaño del catálogo), destacando la necesidad de controles de calidad para nombres. Por otro lado, departments y aisles mostraron integridad en sus IDs únicos, sin duplicados. Finalmente, en order_products, las repeticiones de IDs de orden (4 millones) reflejaron la naturaleza del dataset, donde un pedido puede contener múltiples productos. Estas acciones aseguraron la consistencia de los datos, priorizando la limpieza donde era crítica (pedidos y nombres de productos) y validando la estructura esperada en los demás casos.
#
# El análisis y tratamiento de valores ausentes en los conjuntos de datos permitió identificar patrones lógicos detrás de los datos faltantes, descartando errores y normalizando la información para su correcto procesamiento. En df_productos, los valores nulos en nombres de productos y pasillos se asociaron a categorías "missing" y se reemplazaron por 'unknown', manteniendo la coherencia del dataset. En df_instacart_orders, los nulos en days_since_prior_order correspondieron exclusivamente a primeros pedidos, un comportamiento esperado que no requirió corrección. Por último, los 836 nulos en "add_to_cart_order" se confirmaron como pedidos de un solo producto y se codificaron como 999 para preservar su significado. Estas acciones aseguraron la integridad de los datos, permitiendo su uso confiable en análisis posteriores sin perder información crítica.

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
print(f"El rango de horas es de {df_instacart_orders['order_hour_of_day'].min()} a {df_instacart_orders['order_hour_of_day'].max()} horas")
# Out:
# El rango de horas es de 0 a 23 horas

# %%
print(f"El rango de los dias va de {df_instacart_orders['order_dow'].min()} a {df_instacart_orders['order_dow'].max()}")
# Out:
# El rango de los dias va de 0 a 6

# %% [markdown]
# Las columnas 'order_hour_day' (rango de 24 horas) y 'order_dow' (rango de 7 días) indican que los pedidos se registran con información sobre la hora del día y el día de la semana en que se realizaron, constan de sentido en cada columna y sin errores.

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
pedidos_por_hora = df_instacart_orders.groupby('order_hour_of_day')['user_id'].count()

pedidos_por_hora.plot(x='order_hour_of_day',
                      y='user_id',
                      style='o--',
                      title='Pedidos en el dia',
                      xlabel='Hora del día',
                      ylabel='Número de pedidos',
                      xticks=range(0,24),
                      )

plt.grid(linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# La grafica revela que el mayor volumen de pedidos ocurre entre las 9:00 y 16:00 horas, indicando que los clientes tienden a realizar compras durante el horario diurno, posiblemente asociado a pausas laborales, horas de comida o mayor disponibilidad de tiempo.

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
pedidos_por_dia = df_instacart_orders.groupby('order_dow')['user_id'].count()

pedidos_por_dia.plot(x='order_dow',
                     y='user_id',
                     style='o--',
                     title='Pedidos en la semana',
                     xlabel='Dia de la semana',
                     ylabel='Números de pedidos'
                     )

plt.grid(linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# La grafica muestra que el domingo es el día con mayor volumen de pedidos, destacándose como el preferido por los clientes, mientras que el miércoles presenta la menor actividad, probablemente por ser el día central de la semana laboral.

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
dias_entre_pedidos =  df_instacart_orders.groupby('user_id')['days_since_prior_order'].mean()
print(f"El minimo de son {dias_entre_pedidos.min()} con un maximo de {dias_entre_pedidos.max()} días")
# Out:
# El minimo de son 0.0 con un maximo de 30.0 días

# %%
dias_entre_pedidos.plot(kind='hist',
                        bins=30,
                        alpha=0.7,
                        title='Tiempo entre pedidos',
                        xlabel='Días',
                        ylabel='Números de pedidos')

plt.grid(linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# El tiempo entre pedidos varía desde 0 hasta 30 días, destacándose dos tendencias principales: un primer pico a los 8 días, posiblemente asociado a productos de alta rotación o perecederos, y un segundo pico máximo a los 30 días, que podría corresponder a productos de cadena de frío o compras mensuales recurrentes. Estos patrones sugieren que la frecuencia depende del tipo de producto y las necesidades específicas de los clientes.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Casi todos los ejercicios de esta sección se resolvieron correctamente, bien hecho! Sin embargo, este último A4, necesita de un gráfico tipo histograma para ver cómo está la distribución de los pedidos
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (2da Iteracion)</b> <a class=“tocSkip”></a>
#
# Muy bien realizado el ajuste! Siempre que se trate de analizar distribuciones procura usar un histograma
# </div>

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
pedidos_miercoles = df_instacart_orders[df_instacart_orders['order_dow'] == 3]['order_hour_of_day']
pedidos_miercoles = pedidos_miercoles.value_counts().sort_index().reset_index()
pedidos_miercoles.columns = ['order_hour_of_day','Miércoles']

# %%
pedidos_sabado = df_instacart_orders[df_instacart_orders['order_dow'] == 6]['order_hour_of_day']
pedidos_sabado = pedidos_sabado.value_counts().sort_index().reset_index()
pedidos_sabado.columns = ['order_hour_of_day','Sábado']

# %%
pedidos_miercoles.plot(kind='bar',
                       x='order_hour_of_day',
                       title='Pedidos del Miércoles',
                       xlabel='Horas del día',
                       ylabel='Números de pedidos',
                       legend=False)

plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.xticks(rotation=0)
plt.show()

# %%
pedidos_sabado.plot(kind='bar',
                    x='order_hour_of_day',
                    title='Pedidos del Sábado',
                    xlabel='Horas del día',
                    ylabel='Números de pedidos',
                    legend=False)

plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.xticks(rotation=0)
plt.show()

# %%
df_dias_pedidos = pedidos_miercoles.merge(pedidos_sabado, on='order_hour_of_day')

df_dias_pedidos.plot(
    kind='bar',
    x='order_hour_of_day',
    title='Miércoles Vs Sábado',
    xlabel='Horas del día',
    ylabel='Números de pedidos',
    width=0.9
)

plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Revela diferencias significativas en el comportamiento de pedidos entre miércoles y sábado, destacando que los miércoles presentan un crecimiento más temprano (desde las 6 am) con dos picos (10 am y 3 pm), mientras que los sábados tienen un inicio más tardío (7 am) y un único pico máximo a las 2 pm. Sin embargo, durante la noche, ambos días muestran patrones muy similares, con una disminución constante hasta las 11 pm.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Cada gráfica por separado esta correcta! Pero para poder realizar un análisis de las diferencias por cada hora entre los dos días deberías tener las barras en stack, es decir, por cada hora 2 barras (una por día) y esto mostrarlo en una sola gráfica
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (2da Iteracion)</b> <a class=“tocSkip”></a>
#
# Perfecto! De esta forma es mucho más sencillo hacer la comparación
# </div>

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
distribucion_pedidos = df_instacart_orders.groupby('user_id')['order_number'].nunique().reset_index()
distribucion_pedidos.columns = ['user_id', 'total_pedidos']

# %%
distribucion_pedidos['total_pedidos'].plot(kind='hist',
                                      bins=27,
                                      alpha=0.7,
                                      title='Pedidos por usuario',
                                      xlabel='Pedidos',
                                      ylabel='Usuarios'
                                      )
plt.grid(linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# La grafica muestra que la mayoría de usuarios hacen solo 1 pedido, con una disminución marcada en clientes recurrentes de 2 a 4 pedidos.

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
df_productos_populares = pd.merge(df_order_products,df_products, on='product_id', how='left')

# %%
top_20_productos = (
    df_productos_populares
    .groupby(['product_id', 'product_name'])
    .size()                                   
    .reset_index(name='total_order')        
    .sort_values('total_order', ascending=False)  
    .head(20)                                 
)

# %%
top_20_productos
# Out:
#        product_id              product_name  total_order
# 22808       24852                    BANANA        66050
# 12025       13176    BAG OF ORGANIC BANANAS        53297
# 19370       21137      ORGANIC STRAWBERRIES        37039
# 20077       21903      ORGANIC BABY SPINACH        33971
# 43271       47209      ORGANIC HASS AVOCADO        29773
# 43788       47766           ORGANIC AVOCADO        24689
# 43663       47626               LARGE LEMON        21495
# 15364       16797              STRAWBERRIES        20018
# 24047       26209                     LIMES        19690
# 25556       27845        ORGANIC WHOLE MILK        19600
# 25666       27966       ORGANIC RASPBERRIES        19197
# 21025       22935      ORGANIC YELLOW ONION        15898
# 22908       24964            ORGANIC GARLIC        15292
# 41244       45007          ORGANIC ZUCCHINI        14584
# 35996       39275       ORGANIC BLUEBERRIES        13879
# ...

# %%
ax = top_20_productos.plot(kind='barh',
                           x='product_name',
                           y='total_order',
                           title='Los 20 más populares',
                           xlabel='',
                           ylabel='',
                           legend=False
                    )

ax.invert_yaxis()
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# Las bananas lideran como el producto más pedido, evidenciando preferencias claras y hábitos de compra complementarios.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Buen trabajo con el cálculo! Pero cuando se presenta sólo datos numéricos es más difícil de analizar la métrica, lo mejor sería mostrar una gráfica de barras para ver la diferencia por cada producto
# </div>

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
articulos_por_pedido = df_order_products.groupby('order_id')['product_id'].count().reset_index()
articulos_por_pedido.columns = ['order_id', 'total_articulos']

# %%
print(f"Total de pedidos: {articulos_por_pedido['total_articulos'].count()}")
print(f"Promedio de productos por pedido: {articulos_por_pedido['total_articulos'].mean().round(1)} productos")
print(f"Menor número de productos en un pedido: {articulos_por_pedido['total_articulos'].min()} producto")
print(f"Mayor número de productos en un pedido: {articulos_por_pedido['total_articulos'].max()} productos")
# Out:
# Total de pedidos: 450046
# Promedio de productos por pedido: 10.1 productos
# Menor número de productos en un pedido: 1 producto
# Mayor número de productos en un pedido: 127 productos

# %%
articulos_por_pedido['total_articulos'].plot(kind='hist',
                                             bins=30,
                                             alpha=0.7)

plt.title('Distribución de artículos por pedido')
plt.xlabel('Número de artículos')
plt.ylabel('Número de pedidos')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# El predominio de pedidos de un solo artículo, con una disminución constante en pedidos más grandes, sugiere que los clientes priorizan las compras rápidas y concretas.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Perfecto! Usaste el gráfico adecuado (histograma) para analizar la distribución
# </div>

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
df_order_instacart = pd.merge(df_order_products, # que contiene order_id y product_id
                              df_instacart_orders[['order_id', 'user_id']],  # que tiene user_id
                              on='order_id',
                              how='inner'
)
df_order_instacart_product = pd.merge(df_order_instacart,
                                      df_products[['product_id', 'product_name']],  # Traer nombres
                                      on='product_id',
                                      how='left'
)

# %%
recompras = df_order_instacart_product.groupby(['user_id', 'product_id', 'product_name'])['order_id'].nunique().reset_index()
recompras.columns = ['user_id', 'product_id', 'product_name', 'veces_comprado']

# %%
recompras = recompras[recompras['veces_comprado'] >= 2]

# %%
top_recompras = (recompras.groupby(['product_id', 'product_name'])
    .size()  # Número de usuarios que recompran el producto
    .reset_index(name='usuarios_que_recompran')
    .sort_values('usuarios_que_recompran', ascending=False)
    .head(20)
)
top_recompras
# Out:
#        product_id              product_name  usuarios_que_recompran
# 13385       24852                    BANANA                   14422
# 7064        13176    BAG OF ORGANIC BANANAS                   11612
# 11390       21137      ORGANIC STRAWBERRIES                    7885
# 11803       21903      ORGANIC BABY SPINACH                    7153
# 25462       47209      ORGANIC HASS AVOCADO                    6361
# 25753       47766           ORGANIC AVOCADO                    5063
# 14972       27845        ORGANIC WHOLE MILK                    4212
# 25675       47626               LARGE LEMON                    4021
# 15038       27966       ORGANIC RASPBERRIES                    3947
# 9031        16797              STRAWBERRIES                    3736
# 14097       26209                     LIMES                    3588
# 12364       22935      ORGANIC YELLOW ONION                    2996
# 13444       24964            ORGANIC GARLIC                    2779
# ...

# %%
ax = top_recompras.plot(kind='barh',
                           x='product_name',
                           y='usuarios_que_recompran',
                           title='Los 20 que vuelven a pedirse ',
                           xlabel='',
                           ylabel='',
                           legend=False
                    )

ax.invert_yaxis()
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# Las bananas lideran como el producto más pedido, evidenciando preferencias claras y hábitos de compra complementarios. Esto no solo resalta la importancia de garantizar disponibilidad de estos artículos, sino también oportunidades para crear combos que mejoren la experiencia del cliente.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Al igual que en el ejercicio B4, sería mejor mostrar una gráfica de barras para que sea más comprensible el análisis
# </div>

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
df_order_instacart = pd.merge(df_order_products, # que contiene order_id y product_id
                              df_instacart_orders[['order_id', 'user_id']],  # que tiene user_id
                              on='order_id',
                              how='inner'
)
df_order_instacart_product = pd.merge(df_order_instacart,
                                      df_products[['product_id', 'product_name']],  # Traer nombres
                                      on='product_id',
                                      how='left'
)
df_sorted = df_order_instacart_product.sort_values(['user_id', 'product_id', 'order_id'])
df_sorted['es_recompra'] = df_sorted.duplicated(subset=['user_id', 'product_id'], keep=False)

# %%
proporcion_recompra = (df_sorted.groupby(['product_id', 'product_name'])
    .agg(total_compras=('product_id', 'size'),          # Total de veces que se compró el producto
         total_recompras=('es_recompra', 'sum')         # Veces que fue recompra
    )
    .reset_index()
)
proporcion_recompra['proporcion_recompra'] = (
    proporcion_recompra['total_recompras'] / proporcion_recompra['total_compras']
)
top_recompras = proporcion_recompra.sort_values('proporcion_recompra', ascending=False)

# %%
top_recompras[['product_id', 'product_name', 'total_compras', 'total_recompras', 'proporcion_recompra']].head(20)
# Out:
#        product_id                                       product_name  \
# 45007       49076                ORGANIX TURKEY & VEGETABLE DOG FOOD
# 4114         4507                                            Unknown
# 564           628                                           FRESH OJ
# 41147       44902                  PINEAPPLE COCONUT SPARKLING WATER
# 33761       36812              ALL HAIR TYPES PURE CLEAN STYLING GEL
# 21702       23664      JUST CARROT- CORN & PUMPKIN STAGE 2 BABY FOOD
# 26441       28817  DRY CLEANER'S SECRET FRESH SCENT AT-HOME DRY C...
# 33763       36814                    ORGANIC COCONUT ACAI ENERGY BAR
# 26435       28811                                 DEEP LUNG TINCTURE
# 4116         4509                                            Unknown
# 18387       20065                                MIXED JUMBO RAISINS
# 41452       45225    ARTISAN THIN PIZZA CRUST RUSTIC WHITE FLATBREAD
# 26365       28735                   ULTIAMTE 10 BB CREME CONDITIONER
# ...

# %%
top_recompras[[ 'total_compras', 'total_recompras', 'proporcion_recompra']].corr()
# Out:
#                      total_compras  total_recompras  proporcion_recompra
# total_compras             1.000000         0.976975             0.120615
# total_recompras           0.976975         1.000000             0.109558
# proporcion_recompra       0.120615         0.109558             1.000000

# %% [markdown]
# La proporción de recompra indica que la mayoría de los usuarios que adquirieron un producto lo han pedido más de una vez, mostrando una correlación casi perfecta (0.97). Esto sugiere que, ya sean productos esenciales, sin sustitutos aceptables, o exclusivos en su categoría, los clientes tienden a repetir su compra. Además, los artículos más solicitados presentan una tasa de recompra ligeramente mayor.

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
df_sorted_dos = df_order_instacart.sort_values(['user_id', 'order_id'])
df_sorted_dos['es_recompra'] = df_sorted.duplicated(
    subset=['user_id', 'product_id'],
    keep='first'  # Marca como True desde la segunda compra del producto
)

# %%
df_sorted_dos['es_recompra'] = df_sorted.duplicated(
    subset=['user_id', 'product_id'],
    keep='first'  # Marca como True desde la segunda compra del producto
)
tasa_por_usuario = df_sorted_dos.groupby('user_id')['es_recompra'].mean() * 100
tasa_por_usuario
# Out:
# user_id
# 2          3.846154
# 4          0.000000
# 5          0.000000
# 6          0.000000
# 7          7.142857
#             ...
# 206203     0.000000
# 206206    19.047619
# 206207    28.260870
# 206208    36.000000
# 206209     0.000000
# Name: es_recompra, Length: 149626, dtype: float64

# %% [markdown]
# Este análisis permite identificar los productos con mayor tasa de recompra, lo que facilita la recomendación de artículos similares y la detección de patrones de compra recurrentes en los pedidos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Muy bien hecho el cálculo de las proporciones! Podrías haber usado también `mean()` en el ejercicio C3
# </div>

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
primeros_articulos = df_order_products[df_order_products['add_to_cart_order'] == 1]
top_20_primeros = (
    primeros_articulos
    .groupby('product_id')
    .size()
    .reset_index(name='veces_primer_lugar')
    .sort_values('veces_primer_lugar', ascending=False)
    .head(20)
)

# %%
top_20_primeros = pd.merge(
    top_20_primeros,
    df_products[['product_id', 'product_name']],
    on='product_id',
    how='inner'
)
top_20_primeros.head(20)
# Out:
#     product_id  veces_primer_lugar                 product_name
# 0        24852               15562                       BANANA
# 1        13176               11026       BAG OF ORGANIC BANANAS
# 2        27845                4363           ORGANIC WHOLE MILK
# 3        21137                3946         ORGANIC STRAWBERRIES
# 4        47209                3390         ORGANIC HASS AVOCADO
# 5        21903                3336         ORGANIC BABY SPINACH
# 6        47766                3044              ORGANIC AVOCADO
# 7        19660                2336                 SPRING WATER
# 8        16797                2308                 STRAWBERRIES
# 9        27966                2024          ORGANIC RASPBERRIES
# 10       44632                1914   SPARKLING WATER GRAPEFRUIT
# 11       49235                1797          ORGANIC HALF & HALF
# 12       47626                1737                  LARGE LEMON
# 13         196                1733                         SODA
# ...

# %%
ax = top_20_primeros.plot(kind='barh',
                           x='product_name',
                           y='veces_primer_lugar',
                           title='Los 20 primeros en el carrito',
                           xlabel='',
                           ylabel='',
                           legend=False
                    )

ax.invert_yaxis()
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# El análisis de los productos añadidos primero al carrito revela el comportamiento inicial de compra de los clientes, destacando sus preferencias inmediatas, necesidades prioritarias y percepción de valor.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# Esto se debería presentar también con una gráfica de barras. Y hace falta redactar las conclusiones finales, en esta sección debes hacer un tipo resúmen con los hallazgos más importantes encontrados a lo largo de todo el notebook sobre los diferentes gráficos y cálculos realizados con información que pueda aportar valor a la empresa sobre sus productos
# </div>

# %% [markdown]
# ### Conclusion general del proyecto:

# %% [markdown]
# El análisis revela patrones claros en el comportamiento de compra: los clientes prefieren realizar pedidos durante el horario diurno (9:00–16:00 horas), con mayor actividad los domingos y menor los miércoles, lo que sugiere una relación con la disponibilidad y rutinas semanales. La frecuencia de pedidos muestra picos a los 8 y 30 días, asociados posiblemente a productos perecederos o compras mensuales. La mayoría de los usuarios realiza pocos pedidos (predominando los de un solo artículo), pero con alta tasa de recompra, especialmente en productos esenciales como las bananas, que lideran en popularidad y fidelidad. Estos hallazgos resaltan la importancia de optimizar inventarios para artículos recurrentes, diseñar estrategias horarias y semanales, y potenciar ecomendaciones basadas en hábitos, mejorando así la experiencia del cliente y la eficiencia operativa.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario general (2da Iteracion)</b> <a class=“tocSkip”></a>
#
# Muy buen trabajo con los últimos cambios! Pandas es una librería poderosa para análisis y procesamiento de datos por lo que es una herramienta que hay que manejar a profundidad en esta profesión.
#
# Te invito a mantener las prácticas encontradas en este notebook cómo el usar Markdown para los títulos de cada sección e ir redactando tus conclusiones de las gráficas o cálculos mostrados ya que esto brinda un mejor entendimiento del proceso de análisis seguido cuando compartas tus notebooks con colegas. Saludos!
# </div>
